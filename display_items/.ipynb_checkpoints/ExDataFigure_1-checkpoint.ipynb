# %%
source("/PHShome/kl162/TiRP_github/utils.R")
# Out:
# Loading required package: Matrix
#
# Loaded glmnet 4.1-3
#
# Loading required package: Rcpp
#
# Attaching SeuratObject
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
data = readRDS("../data/seay2016/seay_discovery.rds")

# %%
lens = c("12", "13", "14", "16", "17", "all")
plots = list()
for (i in 1:length(lens)){
    plots[[i]] = mutinf_heatmap(lens[i], add_conditional_MI = TRUE)
}
# Out:
# plot without title
# plot without title
# plot without title
# Error: cannot allocate vector of size 436.7 Mb
# Traceback:
#
# 1. mutinf_heatmap(lens[i], add_conditional_MI = TRUE)
# 2. MutInf(sub[, indi], sub[, indj])
# 3. Entropy(x, base = base)
# 4. ifelse(ptab > 0, ptab * log(ptab, base = base), 0)
# plot without title
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=15)
wrap_plots(plots)
